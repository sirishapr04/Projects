# %%
import pandas as pd
import numpy as np
import datetime
from matplotlib import pyplot as plt
import seaborn as sns

# %%
missing_values = ['']
df = pd.read_csv('data.csv', na_values = missing_values, encoding='unicode_escape')
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataset has 541909 rows and 8 columns.

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# The first column is the InvoiceNo. It is unique to an order and an order can have multiple items with in it. InvoiceNo starts with a 'C' if it is a cancelled order.
#
# The second column is StockCode. It is unique to an item and is alphanumeric.
#
# The third column is Description. It gives a description of each item in an order.
#
# The fourth column is Quantity. It is the amount of any given item that's present in an order.
#
# The fifth column is InvoiceDate. It is the datetime value of when an order was created.
#
# The sixth column is UnitPrice. It is the price of any given item in an order.
#
# The seventh column is CustomerID. It is unique to a customer and helps in identifying who placed any given order.
#
# The eighth column is Country. It gives the information about where the order was placed.

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
print(df.dtypes)
print(df.columns)
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
#Data Cleaning
df = df[~df['Description'].isnull()]
df = df.fillna('NA')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df = df[df['UnitPrice'] > 0]
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns after data cleaning")
print(df.describe())
# Out:
# The dataset has 539392 rows and 8 columns after data cleaning
#             Quantity                    InvoiceDate      UnitPrice
# count  539392.000000                         539392  539392.000000
# mean        9.845904  2011-07-04 16:40:36.232350208       4.673648
# min    -80995.000000            2010-12-01 08:26:00       0.001000
# 25%         1.000000            2011-03-28 11:59:00       1.250000
# 50%         3.000000            2011-07-20 11:50:00       2.080000
# 75%        10.000000            2011-10-19 11:49:00       4.130000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       215.412652                            NaN      94.614722

# %%
print(f"The dataset covers a time period from {df['InvoiceDate'].min()} to {df['InvoiceDate'].max()}")
print(f"There are {len(df['CustomerID'].unique())} unique customers in the dataset")
# Out:
# The dataset covers a time period from 2010-12-01 08:26:00 to 2011-12-09 12:50:00
# There are 4372 unique customers in the dataset

# %%
df_co = df.groupby('CustomerID')['InvoiceNo'].nunique()
df_co = df_co.reset_index().rename(columns = {'InvoiceNo':'Orders'})

# %%
df_co
# Out:
#      CustomerID  Orders
# 0       12346.0       2
# 1       12347.0       7
# 2       12348.0       4
# 3       12349.0       1
# 4       12350.0       1
# ...         ...     ...
# 4367    18281.0       1
# 4368    18282.0       3
# 4369    18283.0      16
# 4370    18287.0       3
# 4371         NA    1610
#
# [4372 rows x 2 columns]

# %%
print(f"Customer Churn% is {len(df_co[df_co['Orders'] <= 1])/len(df_co[df_co['CustomerID'] != 'NA'])*100:.2f}%")
# Out:
# Customer Churn% is 30.02%

# %%
len(df_co[df_co['Orders'] <= 1])
# Out:
# 1312

# %%
plt.figure(figsize = (10,8))
n, bins, patches = plt.hist(df_co[df_co['CustomerID'] != 'NA']['Orders'], bins=20, color='skyblue', edgecolor='black')

plt.title('Distribution of Orders per Customer', fontsize=20)
plt.xlabel('Number of Orders', fontsize=15)
plt.ylabel('Number of Customers', fontsize=15)

for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, n[i], str(int(n[i])), ha='center', va='bottom', fontsize=12)
    
plt.show()

# %%
plt.figure(figsize = (10,8))
n, bins, patches = plt.hist(df_co[(df_co['CustomerID'] != 'NA')&(df_co['Orders'] >25)]['Orders'], bins=20, color='skyblue', edgecolor='black')

plt.title('Distribution of Orders per Customer', fontsize=20)
plt.xlabel('Number of Orders', fontsize=15)
plt.ylabel('Number of Frequency', fontsize=15)

for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, n[i], str(int(n[i])), ha='center', va='bottom', fontsize=12)
    
plt.show()

# %%
plt.figure(figsize = (10,8))
n, bins, patches = plt.hist(df_co[(df_co['CustomerID'] != 'NA')&(df_co['Orders'] >50)]['Orders'], bins=20, color='skyblue', edgecolor='black')

plt.title('Distribution of Orders per Customer', fontsize=20)
plt.xlabel('Number of Orders', fontsize=15)
plt.ylabel('Number of Frequency', fontsize=15)

for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2, n[i], str(int(n[i])), ha='center', va='bottom', fontsize=12)
    
plt.show()

# %%
df_top5c = df_co[df_co['CustomerID']!='NA'].sort_values(by = 'Orders', ascending = False)[:5]
df_top5c
# Out:
#      CustomerID  Orders
# 1894    14911.0     248
# 330     12748.0     223
# 4041    17841.0     169
# 1673    14606.0     128
# 568     13089.0     118

# %%
df_top10p = df['Description'].value_counts()[:10]
df_top10p
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2365
# REGENCY CAKESTAND 3 TIER              2198
# JUMBO BAG RED RETROSPOT               2156
# PARTY BUNTING                         1726
# LUNCH BAG RED RETROSPOT               1638
# ASSORTED COLOUR BIRD ORNAMENT         1501
# SET OF 3 CAKE TINS PANTRY DESIGN      1473
# PACK OF 72 RETROSPOT CAKE CASES       1385
# LUNCH BAG  BLACK SKULL.               1350
# NATURAL SLATE HEART CHALKBOARD        1280
# Name: count, dtype: int64

# %%
df_avgp = df[df['Quantity'] > 0].groupby('Description')['UnitPrice'].mean()
df_avgp
# Out:
# Description
#  4 PURPLE FLOCK DINNER CANDLES       2.455366
#  50'S CHRISTMAS GIFT BAG LARGE       1.426589
#  DOLLY GIRL BEAKER                   1.502123
#  I LOVE LONDON MINI BACKPACK         4.611364
#  I LOVE LONDON MINI RUCKSACK         4.150000
#                                       ...
# ZINC T-LIGHT HOLDER STARS SMALL      0.943673
# ZINC TOP  2 DOOR WOODEN SHELF       21.094167
# ZINC WILLIE WINKIE  CANDLE STICK     1.089963
# ZINC WIRE KITCHEN ORGANISER          9.929375
# ZINC WIRE SWEETHEART LETTER TRAY     3.976522
# Name: UnitPrice, Length: 4026, dtype: float64

# %%
df['Revenue'] = df['Quantity']*df['UnitPrice']
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34

# %%
df_rev = df.groupby('Description')['Revenue'].sum()
df_rev = df_rev.reset_index().sort_values(by = 'Revenue', ascending = False)
df_top10r = df_rev[:10]
df_top10r
# Out:
#                              Description    Revenue
# 1074                      DOTCOM POSTAGE  206245.48
# 2864            REGENCY CAKESTAND 3 TIER  164762.19
# 3859  WHITE HANGING HEART T-LIGHT HOLDER   99668.47
# 2422                       PARTY BUNTING   98302.98
# 1825             JUMBO BAG RED RETROSPOT   92356.03
# 2752                  RABBIT NIGHT LIGHT   66756.59
# 2703                             POSTAGE   66230.64
# 2390     PAPER CHAIN KIT 50'S CHRISTMAS    63791.94
# 228        ASSORTED COLOUR BIRD ORNAMENT   58959.73
# 751                        CHILLI LIGHTS   53768.06

# %%
df['year']=df['InvoiceDate'].dt.year
df['month']=df['InvoiceDate'].dt.strftime('%b')
df['month_num'] = df['InvoiceDate'].dt.month
df['day']=df['InvoiceDate'].dt.day
df['weekday']=df['InvoiceDate'].dt.strftime('%A')
df['weekday_num'] = df['InvoiceDate'].dt.strftime('%w')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue  year  \
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30  2010
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00  2010
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
#
#   month  month_num  day    weekday weekday_num
# 0   Dec         12    1  Wednesday           3
# 1   Dec         12    1  Wednesday           3
# 2   Dec         12    1  Wednesday           3
# 3   Dec         12    1  Wednesday           3
# 4   Dec         12    1  Wednesday           3

# %%
df_wdo = df[df['Quantity'] > 0].groupby(['weekday','weekday_num'])['InvoiceNo'].nunique()
df_wdo = df_wdo.reset_index().rename(columns = {'InvoiceNo' : 'Orders'}).sort_values(by = 'weekday_num')
del df_wdo['weekday_num']
df_wdo
# Out:
#      weekday  Orders
# 2     Sunday    2204
# 1     Monday    3126
# 4    Tuesday    3554
# 5  Wednesday    3690
# 3   Thursday    4246
# 0     Friday    3140

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'weekday', y = 'Orders', data = df_wdo)

plt.title('Order count distribution across various weekdays', fontsize = 20)
plt.xlabel('Weekday', fontsize = 15)
plt.ylabel('Order count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)
    
plt.show()

# %%
df['time'] = df['InvoiceDate'].dt.strftime('%H:%M')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country  Revenue  year  \
# 0 2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30  2010
# 1 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
# 2 2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00  2010
# 3 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
# 4 2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34  2010
#
#   month  month_num  day    weekday weekday_num   time
# 0   Dec         12    1  Wednesday           3  08:26
# 1   Dec         12    1  Wednesday           3  08:26
# 2   Dec         12    1  Wednesday           3  08:26
# 3   Dec         12    1  Wednesday           3  08:26
# 4   Dec         12    1  Wednesday           3  08:26

# %%
def time_bin(x) :
    if x.time() < datetime.time(2) :
        return '00:00-02:00'
    elif x.time() < datetime.time(4) :
        return '02:00-04:00'
    elif x.time() < datetime.time(6) : 
        return '04:00-06:00'
    elif x.time() < datetime.time(8) :
        return '06:00-08:00'
    elif x.time() < datetime.time(10) :
        return '08:00-10:00'
    elif x.time() < datetime.time(12) :
        return '10:00-12:00'
    elif x.time() < datetime.time(14) :
        return '12:00-14:00'
    elif x.time() < datetime.time(16) :
        return '14:00-16:00'
    elif x.time() < datetime.time(18) :
        return '16:00-18:00'
    elif x.time() < datetime.time(20) :
        return '18:00-20:00'
    elif x.time() < datetime.time(22) :
        return '20:00-22:00'
    else :
        return '22:00-00:00'

# %%
df['time_bin'] = df['InvoiceDate'].apply(time_bin)
df[['InvoiceDate','time_bin']]
# Out:
#                InvoiceDate     time_bin
# 0      2010-12-01 08:26:00  08:00-10:00
# 1      2010-12-01 08:26:00  08:00-10:00
# 2      2010-12-01 08:26:00  08:00-10:00
# 3      2010-12-01 08:26:00  08:00-10:00
# 4      2010-12-01 08:26:00  08:00-10:00
# ...                    ...          ...
# 541904 2011-12-09 12:50:00  12:00-14:00
# 541905 2011-12-09 12:50:00  12:00-14:00
# 541906 2011-12-09 12:50:00  12:00-14:00
# 541907 2011-12-09 12:50:00  12:00-14:00
# 541908 2011-12-09 12:50:00  12:00-14:00
#
# [539392 rows x 2 columns]

# %%
df_time = df[df['Quantity'] > 0].groupby('time_bin')['InvoiceNo'].nunique()
df_time = df_time.reset_index().rename(columns = {'InvoiceNo' : 'Orders'})
df_time
# Out:
#       time_bin  Orders
# 0  06:00-08:00      30
# 1  08:00-10:00    2050
# 2  10:00-12:00    4757
# 3  12:00-14:00    5973
# 4  14:00-16:00    4793
# 5  16:00-18:00    2002
# 6  18:00-20:00     338
# 7  20:00-22:00      18

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'time_bin', y = 'Orders', data = df_time)

plt.title('Order count distribution across various Timeframes in a day', fontsize = 20)
plt.xlabel('Timeframe', fontsize = 15)
plt.ylabel('Order count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)
    
plt.show()

# %%
df_month = df[df['Quantity'] > 0].groupby(['month','month_num'])['InvoiceNo'].nunique()
df_month = df_month.reset_index().rename(columns = {'InvoiceNo' : 'Orders'}).sort_values(by = 'month_num')
del df_month['month_num']
df_month
# Out:
#    month  Orders
# 4    Jan    1086
# 3    Feb    1100
# 7    Mar    1454
# 0    Apr    1246
# 8    May    1681
# 6    Jun    1533
# 5    Jul    1475
# 1    Aug    1361
# 11   Sep    1837
# 10   Oct    2040
# 9    Nov    2769
# 2    Dec    2378

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'month', y = 'Orders', data = df_month)

plt.title('Order count distribution across various months', fontsize = 20)
plt.xlabel('Month', fontsize = 15)
plt.ylabel('Order count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)

plt.show()

# %%
monthly_sales = df.groupby(pd.Grouper(key='InvoiceDate', freq='M'))['Quantity'].sum()
plt.figure(figsize = (10,6))
monthly_sales.plot(kind='area', stacked=True, color = 'Salmon')

plt.title('Monthly Sales Trend', fontsize = 20)
plt.xlabel('Date', fontsize = 15)
plt.ylabel('Total Sales', fontsize = 15)

plt.show()
# Out:
# C:\Users\sp2965\AppData\Local\Temp\ipykernel_12380\662565127.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = df.groupby(pd.Grouper(key='InvoiceDate', freq='M'))['Quantity'].sum()

# %%
df_top5_countries = df[df['Quantity'] > 0].groupby(['Country'])['InvoiceNo'].nunique()
df_top5_countries = df_top5_countries.reset_index().rename(columns = {'InvoiceNo' : 'Orders'}).sort_values(by = 'Orders', ascending = False)[:5]
df_top5_countries
# Out:
#            Country  Orders
# 36  United Kingdom   18019
# 14         Germany     457
# 13          France     392
# 10            EIRE     288
# 3          Belgium      98

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'Country', y = 'Orders', data = df_top5_countries)

plt.title('Order count distribution across Top 5 Countries', fontsize = 20)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('Order count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)
    
plt.show()

# %%
df_top5_countries2 = df[df['Quantity'] > 0]['Country'].value_counts()[1:6]
df_top5_countries2 = df_top5_countries2.reset_index().rename(columns = {'count' : 'Orders'})
df_top5_countries2
# Out:
#        Country  Orders
# 0      Germany    9040
# 1       France    8407
# 2         EIRE    7890
# 3        Spain    2484
# 4  Netherlands    2359

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'Country', y = 'Orders', data = df_top5_countries2, palette="Greens_r")

plt.title('Order count distribution across Top 5 Countries excluding UK', fontsize = 20)
plt.xlabel('Country', fontsize = 15)
plt.ylabel('Order count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)
    
plt.show()
# Out:
# C:\Users\sp2965\AppData\Local\Temp\ipykernel_12380\2937612772.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(x = 'Country', y = 'Orders', data = df_top5_countries2, palette="Greens_r")

# %%
df_avg_ov = df[df['CustomerID'] != 'NA'].groupby(['CustomerID','InvoiceNo','Country'])['Revenue'].sum()
df_avg_ov = df_avg_ov.reset_index()

# %%
df_avg_ov = df_avg_ov[df_avg_ov['CustomerID'].isin(df_co[(df_co['CustomerID'] != 'NA')&(df_co['Orders'] >= 5)]['CustomerID'])]
df_avg_ov = df_avg_ov.groupby(['CustomerID','Country'])['Revenue'].mean()
df_avg_ov = df_avg_ov.reset_index().rename(columns = {'Revenue' : 'Avg_order_value'})
df_avg_ov
# Out:
#       CustomerID         Country  Avg_order_value
# 0        12347.0         Iceland       615.714286
# 1        12352.0          Norway       140.491818
# 2        12359.0          Cyprus      1040.921667
# 3        12362.0         Belgium       396.506154
# 4        12380.0         Belgium       544.112000
# ...          ...             ...              ...
# 1373     18245.0  United Kingdom       313.445000
# 1374     18257.0  United Kingdom       188.781667
# 1375     18260.0  United Kingdom       324.375000
# 1376     18272.0  United Kingdom       437.825714
# 1377     18283.0  United Kingdom       130.930000
#
# [1378 rows x 3 columns]

# %%
plt.figure(figsize = (6,12))
sns.boxplot(data = df_avg_ov, x = 'Avg_order_value', y = 'Country')
plt.title('Average Order value distribution/customer across Countries', fontsize = 20)
plt.xlabel('Average Order Value', fontsize = 15)
plt.ylabel('Country', fontsize = 15)
plt.show()

# %%
def first_order(cust_id) :
    return df[df['CustomerID'] == cust_id]['InvoiceDate'].min()
def last_order(cust_id) :
    return df[df['CustomerID'] == cust_id]['InvoiceDate'].max()

# %%
df_cust = df[['CustomerID']].loc[df.CustomerID != 'NA'].drop_duplicates()

# %%
df_cust['First_order_date'] = df_cust['CustomerID'].apply(first_order)

# %%
df_cust['Last_order_date'] = df_cust['CustomerID'].apply(last_order)

# %%
df_cust
# Out:
#        CustomerID    First_order_date     Last_order_date
# 0         17850.0 2010-12-01 08:26:00 2011-02-10 14:38:00
# 9         13047.0 2010-12-01 08:34:00 2011-11-08 12:10:00
# 26        12583.0 2010-12-01 08:45:00 2011-12-07 08:07:00
# 46        13748.0 2010-12-01 09:00:00 2011-09-05 09:45:00
# 65        15100.0 2010-12-01 09:09:00 2011-01-13 17:09:00
# ...           ...                 ...                 ...
# 536969    13436.0 2011-12-08 10:33:00 2011-12-08 10:33:00
# 537255    15520.0 2011-12-08 10:58:00 2011-12-08 10:58:00
# 538064    13298.0 2011-12-08 13:11:00 2011-12-08 13:11:00
# 538812    14569.0 2011-12-08 14:58:00 2011-12-08 14:58:00
# 541768    12713.0 2011-12-09 12:16:00 2011-12-09 12:16:00
#
# [4371 rows x 3 columns]

# %%
df_co = df_co[df_co['CustomerID'] != 'NA']

# %%
df_cust = df_cust.merge(df_co, left_on = 'CustomerID', right_on = 'CustomerID')
df_cust['Days_active'] = df_cust['Last_order_date'] - df_cust['First_order_date']
df_cust
# Out:
#      CustomerID    First_order_date     Last_order_date  Orders  \
# 0       17850.0 2010-12-01 08:26:00 2011-02-10 14:38:00      35
# 1       13047.0 2010-12-01 08:34:00 2011-11-08 12:10:00      18
# 2       12583.0 2010-12-01 08:45:00 2011-12-07 08:07:00      18
# 3       13748.0 2010-12-01 09:00:00 2011-09-05 09:45:00       5
# 4       15100.0 2010-12-01 09:09:00 2011-01-13 17:09:00       6
# ...         ...                 ...                 ...     ...
# 4366    13436.0 2011-12-08 10:33:00 2011-12-08 10:33:00       1
# 4367    15520.0 2011-12-08 10:58:00 2011-12-08 10:58:00       1
# 4368    13298.0 2011-12-08 13:11:00 2011-12-08 13:11:00       1
# 4369    14569.0 2011-12-08 14:58:00 2011-12-08 14:58:00       1
# 4370    12713.0 2011-12-09 12:16:00 2011-12-09 12:16:00       1
#
#            Days_active
# 0     71 days 06:12:00
# 1    342 days 03:36:00
# 2    370 days 23:22:00
# 3    278 days 00:45:00
# 4     43 days 08:00:00
# ...                ...
# 4366   0 days 00:00:00
# 4367   0 days 00:00:00
# 4368   0 days 00:00:00
# 4369   0 days 00:00:00
# 4370   0 days 00:00:00
#
# [4371 rows x 5 columns]

# %%
print(f"Average Active Time for a given customer is ~{round(df_cust['Days_active'].mean().total_seconds()/86400)} days")
# Out:
# Average Active Time for a given customer is ~134 days

# %%
print(f"Average Active Time for a given customer who ordered at least twice is ~{round(df_cust[df_cust['Orders'] > 1]['Days_active'].mean().total_seconds()/86400)} days")
# Out:
# Average Active Time for a given customer who ordered at least twice is ~191 days

# %%
print(f"Average Active Time for a given customer who ordered at least 5 times is ~{round(df_cust[df_cust['Orders'] >= 5]['Days_active'].mean().total_seconds()/86400)} days")
# Out:
# Average Active Time for a given customer who ordered at least 5 times is ~266 days

# %%
df_cust['Days_active'] = df_cust['Days_active'].apply(lambda x : round(x.total_seconds()/86400))
df_cust['Days_active'] = df_cust['Days_active'].apply(lambda x : 1 if x == 0 else x)
df_cust
# Out:
#      CustomerID    First_order_date     Last_order_date  Orders  Days_active
# 0       17850.0 2010-12-01 08:26:00 2011-02-10 14:38:00      35           71
# 1       13047.0 2010-12-01 08:34:00 2011-11-08 12:10:00      18          342
# 2       12583.0 2010-12-01 08:45:00 2011-12-07 08:07:00      18          371
# 3       13748.0 2010-12-01 09:00:00 2011-09-05 09:45:00       5          278
# 4       15100.0 2010-12-01 09:09:00 2011-01-13 17:09:00       6           43
# ...         ...                 ...                 ...     ...          ...
# 4366    13436.0 2011-12-08 10:33:00 2011-12-08 10:33:00       1            1
# 4367    15520.0 2011-12-08 10:58:00 2011-12-08 10:58:00       1            1
# 4368    13298.0 2011-12-08 13:11:00 2011-12-08 13:11:00       1            1
# 4369    14569.0 2011-12-08 14:58:00 2011-12-08 14:58:00       1            1
# 4370    12713.0 2011-12-09 12:16:00 2011-12-09 12:16:00       1            1
#
# [4371 rows x 5 columns]

# %%
df_cust['Order_frequency'] = df_cust['Days_active']/df_cust['Orders']
df_cust
# Out:
#      CustomerID    First_order_date     Last_order_date  Orders  Days_active  \
# 0       17850.0 2010-12-01 08:26:00 2011-02-10 14:38:00      35           71
# 1       13047.0 2010-12-01 08:34:00 2011-11-08 12:10:00      18          342
# 2       12583.0 2010-12-01 08:45:00 2011-12-07 08:07:00      18          371
# 3       13748.0 2010-12-01 09:00:00 2011-09-05 09:45:00       5          278
# 4       15100.0 2010-12-01 09:09:00 2011-01-13 17:09:00       6           43
# ...         ...                 ...                 ...     ...          ...
# 4366    13436.0 2011-12-08 10:33:00 2011-12-08 10:33:00       1            1
# 4367    15520.0 2011-12-08 10:58:00 2011-12-08 10:58:00       1            1
# 4368    13298.0 2011-12-08 13:11:00 2011-12-08 13:11:00       1            1
# 4369    14569.0 2011-12-08 14:58:00 2011-12-08 14:58:00       1            1
# 4370    12713.0 2011-12-09 12:16:00 2011-12-09 12:16:00       1            1
#
#       Order_frequency
# 0            2.028571
# 1           19.000000
# 2           20.611111
# 3           55.600000
# 4            7.166667
# ...               ...
# 4366         1.000000
# 4367         1.000000
# 4368         1.000000
# 4369         1.000000
# 4370         1.000000
#
# [4371 rows x 6 columns]

# %%
df_cust[df_cust['Orders'] > 1]
# Out:
#      CustomerID    First_order_date     Last_order_date  Orders  Days_active  \
# 0       17850.0 2010-12-01 08:26:00 2011-02-10 14:38:00      35           71
# 1       13047.0 2010-12-01 08:34:00 2011-11-08 12:10:00      18          342
# 2       12583.0 2010-12-01 08:45:00 2011-12-07 08:07:00      18          371
# 3       13748.0 2010-12-01 09:00:00 2011-09-05 09:45:00       5          278
# 4       15100.0 2010-12-01 09:09:00 2011-01-13 17:09:00       6           43
# ...         ...                 ...                 ...     ...          ...
# 4323    13521.0 2011-11-29 15:09:00 2011-12-08 13:50:00       3            9
# 4328    15060.0 2011-11-30 14:03:00 2011-12-01 13:47:00       4            1
# 4333    12558.0 2011-12-02 10:41:00 2011-12-08 10:14:00       2            6
# 4361    16000.0 2011-12-07 12:14:00 2011-12-07 12:17:00       3            1
# 4363    14087.0 2011-12-07 12:28:00 2011-12-07 12:41:00       2            1
#
#       Order_frequency
# 0            2.028571
# 1           19.000000
# 2           20.611111
# 3           55.600000
# 4            7.166667
# ...               ...
# 4323         3.000000
# 4328         0.250000
# 4333         3.000000
# 4361         0.333333
# 4363         0.500000
#
# [3059 rows x 6 columns]

# %%
plt.figure(figsize = (10,6))
sns.histplot(df_cust['Order_frequency'], bins = 50)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.histplot(df_cust[df_cust['Orders'] >= 5]['Order_frequency'], bins = 50)
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.histplot(df_cust[df_cust['Orders'] >= 10]['Order_frequency'], bins = 50)
plt.show()

# %%
df_cancelled = df[df['InvoiceNo'].str[0] == 'C']
df_cancelled
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 141    2010-12-01 09:41:00      27.50    14527.0  United Kingdom   -27.50
# 154    2010-12-01 09:49:00       4.65    15311.0  United Kingdom    -4.65
# 235    2010-12-01 10:24:00       1.65    17548.0  United Kingdom   -19.80
# 236    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    -6.96
# 237    2010-12-01 10:24:00       0.29    17548.0  United Kingdom    -6.96
# ...                    ...        ...        ...             ...      ...
# 540449 2011-12-09 09:57:00       0.83    14397.0  United Kingdom    -9.13
# 541541 2011-12-09 10:28:00     224.69    15498.0  United Kingdom  -224.69
# 541715 2011-12-09 11:57:00      10.95    15311.0  United Kingdom   -54.75
# 541716 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    -1.25
# 541717 2011-12-09 11:58:00       1.25    17315.0  United Kingdom    -6.25
#
#         year month  month_num  day    weekday weekday_num   time     time_bin
# 141     2010   Dec         12    1  Wednesday           3  09:41  08:00-10:00
# 154     2010   Dec         12    1  Wednesday           3  09:49  08:00-10:00
# 235     2010   Dec         12    1  Wednesday           3  10:24  10:00-12:00
# 236     2010   Dec         12    1  Wednesday           3  10:24  10:00-12:00
# 237     2010   Dec         12    1  Wednesday           3  10:24  10:00-12:00
# ...      ...   ...        ...  ...        ...         ...    ...          ...
# 540449  2011   Dec         12    9     Friday           5  09:57  08:00-10:00
# 541541  2011   Dec         12    9     Friday           5  10:28  10:00-12:00
# 541715  2011   Dec         12    9     Friday           5  11:57  10:00-12:00
# 541716  2011   Dec         12    9     Friday           5  11:58  10:00-12:00
# 541717  2011   Dec         12    9     Friday           5  11:58  10:00-12:00
#
# [9288 rows x 17 columns]

# %%
df_successful = df[df['InvoiceNo'].str[0] != 'C']
df_successful
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country  Revenue  \
# 0      2010-12-01 08:26:00       2.55    17850.0  United Kingdom    15.30
# 1      2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 2      2010-12-01 08:26:00       2.75    17850.0  United Kingdom    22.00
# 3      2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# 4      2010-12-01 08:26:00       3.39    17850.0  United Kingdom    20.34
# ...                    ...        ...        ...             ...      ...
# 541904 2011-12-09 12:50:00       0.85    12680.0          France    10.20
# 541905 2011-12-09 12:50:00       2.10    12680.0          France    12.60
# 541906 2011-12-09 12:50:00       4.15    12680.0          France    16.60
# 541907 2011-12-09 12:50:00       4.15    12680.0          France    16.60
# 541908 2011-12-09 12:50:00       4.95    12680.0          France    14.85
#
#         year month  month_num  day    weekday weekday_num   time     time_bin
# 0       2010   Dec         12    1  Wednesday           3  08:26  08:00-10:00
# 1       2010   Dec         12    1  Wednesday           3  08:26  08:00-10:00
# 2       2010   Dec         12    1  Wednesday           3  08:26  08:00-10:00
# 3       2010   Dec         12    1  Wednesday           3  08:26  08:00-10:00
# 4       2010   Dec         12    1  Wednesday           3  08:26  08:00-10:00
# ...      ...   ...        ...  ...        ...         ...    ...          ...
# 541904  2011   Dec         12    9     Friday           5  12:50  12:00-14:00
# 541905  2011   Dec         12    9     Friday           5  12:50  12:00-14:00
# 541906  2011   Dec         12    9     Friday           5  12:50  12:00-14:00
# 541907  2011   Dec         12    9     Friday           5  12:50  12:00-14:00
# 541908  2011   Dec         12    9     Friday           5  12:50  12:00-14:00
#
# [530104 rows x 17 columns]

# %%
cancelled_orders = len(df_cancelled['InvoiceNo'].unique())
successful_orders = len(df_successful['InvoiceNo'].unique())
print(f"The percentage of orders that have been cancelled is {cancelled_orders/successful_orders*100:.2f}%")
# Out:
# The percentage of orders that have been cancelled is 19.22%

# %%
df_prod = df_cancelled['Description'].value_counts()
df_prod = df_prod.reset_index().rename(columns = {'Description' : 'Product', 'count' : 'Cancellations'})
df_prod
# Out:
#                                   Product  Cancellations
# 0                                  Manual            244
# 1                REGENCY CAKESTAND 3 TIER            181
# 2                                 POSTAGE            126
# 3                JAM MAKING SET WITH JARS             87
# 4                                Discount             77
# ...                                   ...            ...
# 1967  RETRO LONGBOARD IRONING BOARD COVER              1
# 1968         DOLLY GIRL CHILDRENS EGG CUP              1
# 1969        ENGLISH ROSE NOTEBOOK A7 SIZE              1
# 1970       PINK SMALL JEWELLED PHOTOFRAME              1
# 1971          PAPER CRAFT , LITTLE BIRDIE              1
#
# [1972 rows x 2 columns]

# %%
plt.figure(figsize = (10,10))
df_cancelled['Description'].value_counts()[:10].plot(kind='pie', autopct='%1.1f%%')
plt.title('Cancellation distribution across various Products', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=(10, 8))

corr = df.corr(numeric_only=True)
mask = np.triu(np.ones_like(corr, dtype=bool))

sns.heatmap(corr, mask=mask, cmap='coolwarm', vmax=1, vmin=-1, center=0, 
            square=True, linewidths=.5, annot=True, fmt=".2f")

plt.title('Correlation Heatmap', fontsize = 20)
plt.show()

# %%
def recency_cerrection(recency):
    ans = str(recency).split(' ')[0]
    return(int(ans))

# %%
today = df['InvoiceDate'].max()
today
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
df['rank'] = df.sort_values(['CustomerID','InvoiceDate']).groupby(['CustomerID'])['InvoiceDate'].rank(method='min').astype(int)

# %%
df_cr = df[df['rank'] == 1]
df_cr['recency'] = pd.to_datetime('2011-12-10') - pd.to_datetime(df_cr['InvoiceDate'])

df_cr['recency'] = df_cr['recency'].apply(recency_cerrection)

df_cr = df_cr[['CustomerID','recency']]
df_cr = df_cr.drop_duplicates()
df_cr.head()
# Out:
# C:\Users\sp2965\AppData\Local\Temp\ipykernel_12380\1916323587.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cr['recency'] = pd.to_datetime('2011-12-10') - pd.to_datetime(df_cr['InvoiceDate'])
# C:\Users\sp2965\AppData\Local\Temp\ipykernel_12380\1916323587.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cr['recency'] = df_cr['recency'].apply(recency_cerrection)
#    CustomerID  recency
# 0     17850.0      373
# 9     13047.0      373
# 26    12583.0      373
# 46    13748.0      373
# 65    15100.0      373

# %%
df_cm = df.groupby('CustomerID')['Revenue'].sum()
df_cm = pd.DataFrame(df_cm).reset_index()
df_cm.head()
# Out:
#   CustomerID  Revenue
# 0    12346.0     0.00
# 1    12347.0  4310.00
# 2    12348.0  1797.24
# 3    12349.0  1757.55
# 4    12350.0   334.40

# %%
df_cf = df_cust[['CustomerID','Order_frequency']]
df_cf
# Out:
#      CustomerID  Order_frequency
# 0       17850.0         2.028571
# 1       13047.0        19.000000
# 2       12583.0        20.611111
# 3       13748.0        55.600000
# 4       15100.0         7.166667
# ...         ...              ...
# 4366    13436.0         1.000000
# 4367    15520.0         1.000000
# 4368    13298.0         1.000000
# 4369    14569.0         1.000000
# 4370    12713.0         1.000000
#
# [4371 rows x 2 columns]

# %%
df_rfm = df_cr.merge(df_cf, on = 'CustomerID').merge(df_cm, on = 'CustomerID').rename(columns = {'Order_frequency' : 'frequency', 'Revenue' : 'monetary'})
df_rfm = df_rfm.sort_values(by = 'CustomerID')
df_rfm
# Out:
#      CustomerID  recency  frequency  monetary
# 1169    12346.0      325   0.500000      0.00
# 438     12347.0      367  52.142857   4310.00
# 873     12348.0      358  70.750000   1797.24
# 4238    12349.0       18   1.000000   1757.55
# 1419    12350.0      310   1.000000    334.40
# ...         ...      ...        ...       ...
# 1837    18280.0      277   1.000000    180.60
# 2855    18281.0      180   1.000000     80.82
# 3233    18282.0      126  39.666667    176.60
# 988     18283.0      337  20.875000   2094.88
# 2692    18287.0      201  53.000000   1837.28
#
# [4371 rows x 4 columns]

# %%
def get_group(Q1, Q2, Q3, value):
    if value <= Q1:
        return '1'
    elif Q1 < value <= Q2:
        return '2'
    elif Q2 < value <= Q3:
        return '3'
    elif Q3 < value:
        return '4'

# %%
freq_Q1, freq_Q2, freq_Q3 = df_rfm['frequency'].quantile([0.25,0.5,0.75])
rece_Q1, rece_Q2, rece_Q3 = df_rfm['recency'].quantile([0.25,0.5,0.75])
mone_Q1, mone_Q2, mone_Q3 = df_rfm['monetary'].quantile([0.25,0.5,0.75])

freq_group = []
for i in range(len(df_rfm)):
    freq = df_rfm.iloc[i]['frequency']
    freq_group.append(get_group(freq_Q1, freq_Q2, freq_Q3, freq))

df_rfm['freq_group'] = freq_group

monetary_group = []
for i in range(len(df_rfm)):
    monetary = df_rfm.iloc[i]['monetary']
    monetary_group.append(get_group(mone_Q1, mone_Q2, mone_Q3, monetary)) 

df_rfm['monetary_group'] = monetary_group

recency_group = []
for i in range(len(df_rfm)):
    recency = df_rfm.iloc[i]['recency']
    recency_group.append(get_group(rece_Q1, rece_Q2, rece_Q3, recency)) 

df_rfm['recency_group'] = recency_group

df_rfm.head()
# Out:
#      CustomerID  recency  frequency  monetary freq_group monetary_group  \
# 1169    12346.0      325   0.500000      0.00          1              1
# 438     12347.0      367  52.142857   4310.00          4              4
# 873     12348.0      358  70.750000   1797.24          4              4
# 4238    12349.0       18   1.000000   1757.55          1              4
# 1419    12350.0      310   1.000000    334.40          1              2
#
#      recency_group
# 1169             3
# 438              4
# 873              4
# 4238             1
# 1419             3

# %%
df_rfm['rfm'] = df_rfm['recency_group'] + df_rfm['freq_group'] + df_rfm['monetary_group']
df_rfm.head()
# Out:
#      CustomerID  recency  frequency  monetary freq_group monetary_group  \
# 1169    12346.0      325   0.500000      0.00          1              1
# 438     12347.0      367  52.142857   4310.00          4              4
# 873     12348.0      358  70.750000   1797.24          4              4
# 4238    12349.0       18   1.000000   1757.55          1              4
# 1419    12350.0      310   1.000000    334.40          1              2
#
#      recency_group  rfm
# 1169             3  311
# 438              4  444
# 873              4  444
# 4238             1  114
# 1419             3  312

# %%
def get_segment(rfm):
    if rfm == '144':
        return 'Best'
    elif rfm == '344':
        return 'Almost Lost'
    elif rfm == '444':
        return 'Lost Big Spenders'
    elif rfm == '441':
        return 'Lost Cheap'
    elif rfm[1] == '4':
        return 'Loyal'
    elif rfm[2] == '4':
        return 'Big Spenders'
    else:
        return 'Normal'

# %%
df_rfm['Segment'] = df_rfm['rfm'].apply(get_segment)
df_rfm.head()
# Out:
#      CustomerID  recency  frequency  monetary freq_group monetary_group  \
# 1169    12346.0      325   0.500000      0.00          1              1
# 438     12347.0      367  52.142857   4310.00          4              4
# 873     12348.0      358  70.750000   1797.24          4              4
# 4238    12349.0       18   1.000000   1757.55          1              4
# 1419    12350.0      310   1.000000    334.40          1              2
#
#      recency_group  rfm            Segment
# 1169             3  311             Normal
# 438              4  444  Lost Big Spenders
# 873              4  444  Lost Big Spenders
# 4238             1  114       Big Spenders
# 1419             3  312             Normal

# %%
df_cust_seg = df_rfm[['CustomerID','Segment']]
df_cust_seg.head()
# Out:
#      CustomerID            Segment
# 1169    12346.0             Normal
# 438     12347.0  Lost Big Spenders
# 873     12348.0  Lost Big Spenders
# 4238    12349.0       Big Spenders
# 1419    12350.0             Normal

# %%
segment_group = df_cust_seg.groupby('Segment').count()
segment_group = segment_group.reset_index().rename(columns = {'CustomerID':'Count'})
segment_group.head()
# Out:
#              Segment  Count
# 0        Almost Lost     82
# 1       Big Spenders    877
# 2  Lost Big Spenders    108
# 3         Lost Cheap     39
# 4              Loyal    862

# %%
plt.figure(figsize = (10,6))
barplot = sns.barplot(x = 'Segment', y = 'Count', data = segment_group)

plt.title('Customer distribution among the segments', fontsize = 20)
plt.xlabel('Segment', fontsize = 15)
plt.ylabel('Customer Count', fontsize = 15)

for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.1f'),  # format the value to one decimal point
                     (p.get_x() + p.get_width() / 2., p.get_height()),  # position of the annotation
                     ha='center', va='center', xytext=(0, 10),  # horizontal/vertical alignment and text padding
                     textcoords='offset points', fontsize=12)
    
plt.show()
